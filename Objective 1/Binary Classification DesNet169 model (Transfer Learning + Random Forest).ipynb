# %%
#import necessary libraries 

# !pip install tensorflow
# !pip install keras 
# !pip install opencv-python

import numpy as np 
import matplotlib.pyplot as plt
import glob
import cv2
from keras.models import Model, Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
import os
import seaborn as sns
from keras.applications.densenet import DenseNet169
# Out:
# Requirement already satisfied: tensorflow in c:\python36\lib\site-packages (2.6.2)
# Requirement already satisfied: clang~=5.0 in c:\python36\lib\site-packages (from tensorflow) (5.0)
# Requirement already satisfied: termcolor~=1.1.0 in c:\python36\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in c:\python36\lib\site-packages (from tensorflow) (1.48.2)
# Requirement already satisfied: astunparse~=1.6.3 in c:\python36\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: wheel~=0.35 in c:\python36\lib\site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wrapt~=1.12.1 in c:\python36\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: keras<2.7,>=2.6.0 in c:\python36\lib\site-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: gast==0.4.0 in c:\python36\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: numpy~=1.19.2 in c:\python36\lib\site-packages (from tensorflow) (1.19.5)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\python36\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: h5py~=3.1.0 in c:\python36\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: tensorboard<2.7,>=2.6.0 in c:\python36\lib\site-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\python36\lib\site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: protobuf>=3.9.2 in c:\python36\lib\site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: six~=1.15.0 in c:\python36\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: tensorflow-estimator<2.7,>=2.6.0 in c:\python36\lib\site-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: absl-py~=0.10 in c:\python36\lib\site-packages (from tensorflow) (0.15.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\python36\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\python36\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: google-pasta~=0.2 in c:\python36\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: cached-property in c:\python36\lib\site-packages (from h5py~=3.1.0->tensorflow) (1.5.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\python36\lib\site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (3.3.7)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\python36\lib\site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\python36\lib\site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (2.27.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\python36\lib\site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (1.35.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\python36\lib\site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (59.6.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\python36\lib\site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\python36\lib\site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (2.0.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\python36\lib\site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (0.4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\python36\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\python36\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\python36\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\python36\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\python36\lib\site-packages (from markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow) (4.8.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\python36\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\python36\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python36\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python36\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (1.26.14)
# Requirement already satisfied: dataclasses in c:\python36\lib\site-packages (from werkzeug>=0.11.15->tensorboard<2.7,>=2.6.0->tensorflow) (0.8)
# Requirement already satisfied: zipp>=0.5 in c:\python36\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\python36\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\python36\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow) (3.2.2)
# Requirement already satisfied: keras in c:\python36\lib\site-packages (2.6.0)
# Requirement already satisfied: opencv-python in c:\python36\lib\site-packages (3.4.13.47)
# Requirement already satisfied: numpy>=1.13.3 in c:\python36\lib\site-packages (from opencv-python) (1.19.5)

# %%
#Resize images 
SIZE = 256

# %%
# Capture training data and labels into respective lists

train_images = []
train_labels = [] 

for directory_path in glob.glob(r"C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train/*"):
    label = directory_path.split("\\")[-1]
    print(label)
    for img_path in glob.glob(os.path.join(directory_path, "*.png")):
        print(img_path)
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE, SIZE))
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        train_images.append(img)
        train_labels.append(label)
# Out:
# fracture
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (10).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (11).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (12).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (13).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1361).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1362).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1363).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1364).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1365).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1366).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1367).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1368).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1369).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1370).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1371).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1372).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1373).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1374).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1375).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1376).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1377).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1378).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1379).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1380).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (14).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1481).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1482).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1483).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1484).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1485).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1486).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1487).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1488).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1489).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1490).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1491).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1492).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1493).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1494).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1495).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1496).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1497).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1498).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1499).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (15).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1500).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1501).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1502).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1503).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1504).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1505).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1506).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1507).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1508).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1509).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1510).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1511).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1512).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1513).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1514).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1515).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1516).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1517).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1518).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1519).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1520).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1521).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1522).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1523).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1524).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1525).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1526).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1527).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1528).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1529).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1530).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1531).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1532).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1533).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1534).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1535).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1536).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1537).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1538).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1539).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1540).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1541).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1542).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1543).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1544).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1545).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1546).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1547).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1548).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1549).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1550).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1551).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1552).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1553).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1554).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1555).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1556).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1557).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1558).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1559).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1560).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1561).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1562).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1563).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1564).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1565).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1566).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1567).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1568).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1569).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1570).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1571).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1572).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1573).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1574).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1575).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1576).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1577).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1578).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1579).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1580).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1581).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1582).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1583).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1584).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1585).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1586).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1587).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1588).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1589).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1590).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1591).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1592).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1593).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1594).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1595).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1596).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1597).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1598).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1599).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (16).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1600).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1601).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1602).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1603).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1604).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1605).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1606).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1607).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1608).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1609).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1610).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1611).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1612).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1613).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1614).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1615).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1616).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1617).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1618).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1619).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1620).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (17).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1741).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (1742).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\fracture\fracture (
png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (763).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (764).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (765).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (766).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (767).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (768).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (769).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (77).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (770).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (771).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (772).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (773).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (774).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (775).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (776).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (777).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (778).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (779).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (78).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (79).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (80).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (81).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (82).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (83).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (84).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (85).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (86).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (87).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (88).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (880).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (881).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (882).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (883).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (884).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (885).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (886).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (887).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (888).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (889).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (89).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (890).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (891).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (892).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (893).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (894).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (895).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (896).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (897).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (898).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (899).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (90).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (900).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (901).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (902).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (903).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (904).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (905).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (906).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (907).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (908).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (909).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (91).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (910).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (911).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (912).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (913).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (914).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (915).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (916).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (917).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (918).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (919).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (92).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (920).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (921).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (922).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (923).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (924).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (925).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (926).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (927).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (928).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (929).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (93).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (930).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (931).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (932).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (933).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (934).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (935).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (936).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (937).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (938).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (939).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (94).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (940).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (941).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (942).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (943).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (944).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (945).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (946).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (947).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (948).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (949).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (95).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (950).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (951).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (952).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (953).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (954).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (955).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (956).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (957).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (958).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (959).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (96).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (960).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (961).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (962).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (963).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (964).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (965).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (966).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (967).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (968).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (969).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (97).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (970).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (971).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (972).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (973).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (974).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (975).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (976).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (977).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (978).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (979).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (98).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (980).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (981).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (982).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (983).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (984).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (985).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (986).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (987).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (988).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (989).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (99).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (990).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (991).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (992).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (993).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (994).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (995).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (996).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (997).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (998).png
# C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\train\non-fracture\non-fracture (999).png

# %%
#Convert lists to arrays 

train_images = np.array(train_images)
train_labels = np.array(train_labels)

# %%
# Capture test/validation data and labels into respective lists
test_images = []
test_labels = [] 
for directory_path in glob.glob(r"C:\Users\user\Desktop\Nikhil Stuff Dont Open\new binary\validation/*"):
    fruit_label = directory_path.split("\\")[-1]
    for img_path in glob.glob(os.path.join(directory_path, "*.png")):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        img = cv2.resize(img, (SIZE, SIZE))
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        test_images.append(img)
        test_labels.append(fruit_label)

# %%
#Convert lists to arrays   
test_images = np.array(test_images)
test_labels = np.array(test_labels)

# %%
#Encode labels from text to integers.
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(test_labels)
test_labels_encoded = le.transform(test_labels)
le.fit(train_labels)
train_labels_encoded = le.transform(train_labels)

# %%
#Split data into test and train datasets 

x_train, y_train, x_test, y_test = train_images, train_labels_encoded, test_images, test_labels_encoded

# %%
# Normalize pixel values to between 0 and 1

x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
#One hot encode y values for neural network. 

from tensorflow.keras.utils import to_categorical
y_train_one_hot = to_categorical(y_train)
y_test_one_hot = to_categorical(y_test)

# %%
#Load model wothout classifier/fully connected layers

dense_model = DenseNet169(weights='imagenet', include_top = False, input_shape=(SIZE, SIZE, 3))

# %%
#Make loaded layers as non-trainable. This is important as we want to work with pre-trained weights

for layer in dense_model.layers:
	layer.trainable = False

# %%
 #Trainable parameters will be 0
    
dense_model.summary()
# Out:
# Model: "densenet169"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 262, 262, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 128, 128, 64) 9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 128, 128, 64) 256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 128, 128, 64) 0           conv1/bn[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 130, 130, 64) 0           conv1/relu[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 64, 64, 64)   0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 64, 64, 64)   256         pool1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_relu (Activation (None, 64, 64, 64)   0           conv2_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 64, 64, 128)  8192        conv2_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 64, 64, 128)  512         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 64, 64, 128)  0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 64, 64, 32)   36864       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_concat (Concatenat (None, 64, 64, 96)   0           pool1[0][0]
#                                                                  conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_bn (BatchNormali (None, 64, 64, 96)   384         conv2_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_relu (Activation (None, 64, 64, 96)   0           conv2_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 64, 64, 128)  12288       conv2_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 64, 64, 128)  512         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 64, 64, 128)  0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 64, 64, 32)   36864       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_concat (Concatenat (None, 64, 64, 128)  0           conv2_block1_concat[0][0]
#                                                                  conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_bn (BatchNormali (None, 64, 64, 128)  512         conv2_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_relu (Activation (None, 64, 64, 128)  0           conv2_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 64, 64, 128)  16384       conv2_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 64, 64, 128)  512         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 64, 64, 128)  0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 64, 64, 32)   36864       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_concat (Concatenat (None, 64, 64, 160)  0           conv2_block2_concat[0][0]
#                                                                  conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_bn (BatchNormali (None, 64, 64, 160)  640         conv2_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_relu (Activation (None, 64, 64, 160)  0           conv2_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)    (None, 64, 64, 128)  20480       conv2_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormali (None, 64, 64, 128)  512         conv2_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_relu (Activation (None, 64, 64, 128)  0           conv2_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)    (None, 64, 64, 32)   36864       conv2_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_concat (Concatenat (None, 64, 64, 192)  0           conv2_block3_concat[0][0]
#                                                                  conv2_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_bn (BatchNormali (None, 64, 64, 192)  768         conv2_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_relu (Activation (None, 64, 64, 192)  0           conv2_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_conv (Conv2D)    (None, 64, 64, 128)  24576       conv2_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_bn (BatchNormali (None, 64, 64, 128)  512         conv2_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_relu (Activation (None, 64, 64, 128)  0           conv2_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_2_conv (Conv2D)    (None, 64, 64, 32)   36864       conv2_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_concat (Concatenat (None, 64, 64, 224)  0           conv2_block4_concat[0][0]
#                                                                  conv2_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_bn (BatchNormali (None, 64, 64, 224)  896         conv2_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_relu (Activation (None, 64, 64, 224)  0           conv2_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_conv (Conv2D)    (None, 64, 64, 128)  28672       conv2_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_bn (BatchNormali (None, 64, 64, 128)  512         conv2_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_relu (Activation (None, 64, 64, 128)  0           conv2_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_2_conv (Conv2D)    (None, 64, 64, 32)   36864       conv2_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_concat (Concatenat (None, 64, 64, 256)  0           conv2_block5_concat[0][0]
#                                                                  conv2_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# pool2_bn (BatchNormalization)   (None, 64, 64, 256)  1024        conv2_block6_concat[0][0]
# __________________________________________________________________________________________________
# pool2_relu (Activation)         (None, 64, 64, 256)  0           pool2_bn[0][0]
# __________________________________________________________________________________________________
# pool2_conv (Conv2D)             (None, 64, 64, 128)  32768       pool2_relu[0][0]
# __________________________________________________________________________________________________
# pool2_pool (AveragePooling2D)   (None, 32, 32, 128)  0           pool2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 32, 32, 128)  512         pool2_pool[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_relu (Activation (None, 32, 32, 128)  0           conv3_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 32, 32, 128)  16384       conv3_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 32, 32, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_concat (Concatenat (None, 32, 32, 160)  0           pool2_pool[0][0]
#                                                                  conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_bn (BatchNormali (None, 32, 32, 160)  640         conv3_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_relu (Activation (None, 32, 32, 160)  0           conv3_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 32, 32, 128)  20480       conv3_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 32, 32, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_concat (Concatenat (None, 32, 32, 192)  0           conv3_block1_concat[0][0]
#                                                                  conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_bn (BatchNormali (None, 32, 32, 192)  768         conv3_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_relu (Activation (None, 32, 32, 192)  0           conv3_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 32, 32, 128)  24576       conv3_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 32, 32, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_concat (Concatenat (None, 32, 32, 224)  0           conv3_block2_concat[0][0]
#                                                                  conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_bn (BatchNormali (None, 32, 32, 224)  896         conv3_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_relu (Activation (None, 32, 32, 224)  0           conv3_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 32, 32, 128)  28672       conv3_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 32, 32, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_concat (Concatenat (None, 32, 32, 256)  0           conv3_block3_concat[0][0]
#                                                                  conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_bn (BatchNormali (None, 32, 32, 256)  1024        conv3_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_relu (Activation (None, 32, 32, 256)  0           conv3_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 32, 32, 128)  32768       conv3_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (Activation (None, 32, 32, 128)  0           conv3_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv3_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_concat (Concatenat (None, 32, 32, 288)  0           conv3_block4_concat[0][0]
#                                                                  conv3_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_bn (BatchNormali (None, 32, 32, 288)  1152        conv3_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_relu (Activation (None, 32, 32, 288)  0           conv3_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 32, 32, 128)  36864       conv3_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (Activation (None, 32, 32, 128)  0           conv3_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv3_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_concat (Concatenat (None, 32, 32, 320)  0           conv3_block5_concat[0][0]
#                                                                  conv3_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_bn (BatchNormali (None, 32, 32, 320)  1280        conv3_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_relu (Activation (None, 32, 32, 320)  0           conv3_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)    (None, 32, 32, 128)  40960       conv3_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_relu (Activation (None, 32, 32, 128)  0           conv3_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv3_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_concat (Concatenat (None, 32, 32, 352)  0           conv3_block6_concat[0][0]
#                                                                  conv3_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_bn (BatchNormali (None, 32, 32, 352)  1408        conv3_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_relu (Activation (None, 32, 32, 352)  0           conv3_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)    (None, 32, 32, 128)  45056       conv3_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_relu (Activation (None, 32, 32, 128)  0           conv3_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv3_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_concat (Concatenat (None, 32, 32, 384)  0           conv3_block7_concat[0][0]
#                                                                  conv3_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_bn (BatchNormali (None, 32, 32, 384)  1536        conv3_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_relu (Activation (None, 32, 32, 384)  0           conv3_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_conv (Conv2D)    (None, 32, 32, 128)  49152       conv3_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_relu (Activation (None, 32, 32, 128)  0           conv3_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv3_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_concat (Concatenat (None, 32, 32, 416)  0           conv3_block8_concat[0][0]
#                                                                  conv3_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_bn (BatchNormal (None, 32, 32, 416)  1664        conv3_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_relu (Activatio (None, 32, 32, 416)  0           conv3_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_conv (Conv2D)   (None, 32, 32, 128)  53248       conv3_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_bn (BatchNormal (None, 32, 32, 128)  512         conv3_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_relu (Activatio (None, 32, 32, 128)  0           conv3_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_2_conv (Conv2D)   (None, 32, 32, 32)   36864       conv3_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_concat (Concatena (None, 32, 32, 448)  0           conv3_block9_concat[0][0]
#                                                                  conv3_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_bn (BatchNormal (None, 32, 32, 448)  1792        conv3_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_relu (Activatio (None, 32, 32, 448)  0           conv3_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_conv (Conv2D)   (None, 32, 32, 128)  57344       conv3_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_bn (BatchNormal (None, 32, 32, 128)  512         conv3_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_relu (Activatio (None, 32, 32, 128)  0           conv3_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_2_conv (Conv2D)   (None, 32, 32, 32)   36864       conv3_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_concat (Concatena (None, 32, 32, 480)  0           conv3_block10_concat[0][0]
#                                                                  conv3_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_bn (BatchNormal (None, 32, 32, 480)  1920        conv3_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_relu (Activatio (None, 32, 32, 480)  0           conv3_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_conv (Conv2D)   (None, 32, 32, 128)  61440       conv3_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_bn (BatchNormal (None, 32, 32, 128)  512         conv3_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_relu (Activatio (None, 32, 32, 128)  0           conv3_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_2_conv (Conv2D)   (None, 32, 32, 32)   36864       conv3_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_concat (Concatena (None, 32, 32, 512)  0           conv3_block11_concat[0][0]
#                                                                  conv3_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# pool3_bn (BatchNormalization)   (None, 32, 32, 512)  2048        conv3_block12_concat[0][0]
# __________________________________________________________________________________________________
# pool3_relu (Activation)         (None, 32, 32, 512)  0           pool3_bn[0][0]
# __________________________________________________________________________________________________
# pool3_conv (Conv2D)             (None, 32, 32, 256)  131072      pool3_relu[0][0]
# __________________________________________________________________________________________________
# pool3_pool (AveragePooling2D)   (None, 16, 16, 256)  0           pool3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 16, 16, 256)  1024        pool3_pool[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_relu (Activation (None, 16, 16, 256)  0           conv4_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 16, 16, 128)  32768       conv4_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 16, 16, 128)  512         conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 16, 16, 128)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_concat (Concatenat (None, 16, 16, 288)  0           pool3_pool[0][0]
#                                                                  conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_bn (BatchNormali (None, 16, 16, 288)  1152        conv4_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_relu (Activation (None, 16, 16, 288)  0           conv4_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 16, 16, 128)  36864       conv4_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 16, 16, 128)  512         conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 16, 16, 128)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_concat (Concatenat (None, 16, 16, 320)  0           conv4_block1_concat[0][0]
#                                                                  conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_bn (BatchNormali (None, 16, 16, 320)  1280        conv4_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_relu (Activation (None, 16, 16, 320)  0           conv4_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 16, 16, 128)  40960       conv4_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 16, 16, 128)  512         conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 16, 16, 128)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_concat (Concatenat (None, 16, 16, 352)  0           conv4_block2_concat[0][0]
#                                                                  conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_bn (BatchNormali (None, 16, 16, 352)  1408        conv4_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_relu (Activation (None, 16, 16, 352)  0           conv4_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 16, 16, 128)  45056       conv4_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 16, 16, 128)  512         conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 16, 16, 128)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_concat (Concatenat (None, 16, 16, 384)  0           conv4_block3_concat[0][0]
#                                                                  conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_bn (BatchNormali (None, 16, 16, 384)  1536        conv4_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_relu (Activation (None, 16, 16, 384)  0           conv4_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 16, 16, 128)  49152       conv4_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 16, 16, 128)  512         conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 16, 16, 128)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_concat (Concatenat (None, 16, 16, 416)  0           conv4_block4_concat[0][0]
#                                                                  conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_bn (BatchNormali (None, 16, 16, 416)  1664        conv4_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_relu (Activation (None, 16, 16, 416)  0           conv4_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 16, 16, 128)  53248       conv4_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 16, 16, 128)  512         conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 16, 16, 128)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_concat (Concatenat (None, 16, 16, 448)  0           conv4_block5_concat[0][0]
#                                                                  conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_bn (BatchNormali (None, 16, 16, 448)  1792        conv4_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_relu (Activation (None, 16, 16, 448)  0           conv4_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 16, 16, 128)  57344       conv4_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 16, 16, 128)  512         conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 16, 16, 128)  0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_concat (Concatenat (None, 16, 16, 480)  0           conv4_block6_concat[0][0]
#                                                                  conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_bn (BatchNormali (None, 16, 16, 480)  1920        conv4_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_relu (Activation (None, 16, 16, 480)  0           conv4_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 16, 16, 128)  61440       conv4_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 16, 16, 128)  512         conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 16, 16, 128)  0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_concat (Concatenat (None, 16, 16, 512)  0           conv4_block7_concat[0][0]
#                                                                  conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_bn (BatchNormali (None, 16, 16, 512)  2048        conv4_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_relu (Activation (None, 16, 16, 512)  0           conv4_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 16, 16, 128)  65536       conv4_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 16, 16, 128)  512         conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 16, 16, 128)  0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_concat (Concatenat (None, 16, 16, 544)  0           conv4_block8_concat[0][0]
#                                                                  conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_bn (BatchNormal (None, 16, 16, 544)  2176        conv4_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_relu (Activatio (None, 16, 16, 544)  0           conv4_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 16, 16, 128)  69632       conv4_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 16, 16, 128)  512         conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 16, 16, 128)  0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 16, 16, 32)   36864       conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_concat (Concatena (None, 16, 16, 576)  0           conv4_block9_concat[0][0]
#                                                                  conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_bn (BatchNormal (None, 16, 16, 576)  2304        conv4_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_relu (Activatio (None, 16, 16, 576)  0           conv4_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 16, 16, 128)  73728       conv4_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 16, 16, 128)  512         conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 16, 16, 128)  0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 16, 16, 32)   36864       conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_concat (Concatena (None, 16, 16, 608)  0           conv4_block10_concat[0][0]
#                                                                  conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_bn (BatchNormal (None, 16, 16, 608)  2432        conv4_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_relu (Activatio (None, 16, 16, 608)  0           conv4_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 16, 16, 128)  77824       conv4_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 16, 16, 128)  512         conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 16, 16, 128)  0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 16, 16, 32)   36864       conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_concat (Concatena (None, 16, 16, 640)  0           conv4_block11_concat[0][0]
#                                                                  conv4_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_0_bn (BatchNormal (None, 16, 16, 640)  2560        conv4_block12_concat[0][0]
# ...
# conv5_block22_2_conv (Conv2D)   (None, 8, 8, 32)     36864       conv5_block22_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block22_concat (Concatena (None, 8, 8, 1344)   0           conv5_block21_concat[0][0]
#                                                                  conv5_block22_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block23_0_bn (BatchNormal (None, 8, 8, 1344)   5376        conv5_block22_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block23_0_relu (Activatio (None, 8, 8, 1344)   0           conv5_block23_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_conv (Conv2D)   (None, 8, 8, 128)    172032      conv5_block23_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_bn (BatchNormal (None, 8, 8, 128)    512         conv5_block23_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_relu (Activatio (None, 8, 8, 128)    0           conv5_block23_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block23_2_conv (Conv2D)   (None, 8, 8, 32)     36864       conv5_block23_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block23_concat (Concatena (None, 8, 8, 1376)   0           conv5_block22_concat[0][0]
#                                                                  conv5_block23_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block24_0_bn (BatchNormal (None, 8, 8, 1376)   5504        conv5_block23_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block24_0_relu (Activatio (None, 8, 8, 1376)   0           conv5_block24_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_conv (Conv2D)   (None, 8, 8, 128)    176128      conv5_block24_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_bn (BatchNormal (None, 8, 8, 128)    512         conv5_block24_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_relu (Activatio (None, 8, 8, 128)    0           conv5_block24_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block24_2_conv (Conv2D)   (None, 8, 8, 32)     36864       conv5_block24_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block24_concat (Concatena (None, 8, 8, 1408)   0           conv5_block23_concat[0][0]
#                                                                  conv5_block24_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block25_0_bn (BatchNormal (None, 8, 8, 1408)   5632        conv5_block24_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block25_0_relu (Activatio (None, 8, 8, 1408)   0           conv5_block25_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_conv (Conv2D)   (None, 8, 8, 128)    180224      conv5_block25_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_bn (BatchNormal (None, 8, 8, 128)    512         conv5_block25_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_relu (Activatio (None, 8, 8, 128)    0           conv5_block25_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block25_2_conv (Conv2D)   (None, 8, 8, 32)     36864       conv5_block25_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block25_concat (Concatena (None, 8, 8, 1440)   0           conv5_block24_concat[0][0]
#                                                                  conv5_block25_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block26_0_bn (BatchNormal (None, 8, 8, 1440)   5760        conv5_block25_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block26_0_relu (Activatio (None, 8, 8, 1440)   0           conv5_block26_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_conv (Conv2D)   (None, 8, 8, 128)    184320      conv5_block26_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_bn (BatchNormal (None, 8, 8, 128)    512         conv5_block26_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_relu (Activatio (None, 8, 8, 128)    0           conv5_block26_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block26_2_conv (Conv2D)   (None, 8, 8, 32)     36864       conv5_block26_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block26_concat (Concatena (None, 8, 8, 1472)   0           conv5_block25_concat[0][0]
#                                                                  conv5_block26_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block27_0_bn (BatchNormal (None, 8, 8, 1472)   5888        conv5_block26_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block27_0_relu (Activatio (None, 8, 8, 1472)   0           conv5_block27_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_conv (Conv2D)   (None, 8, 8, 128)    188416      conv5_block27_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_bn (BatchNormal (None, 8, 8, 128)    512         conv5_block27_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_relu (Activatio (None, 8, 8, 128)    0           conv5_block27_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block27_2_conv (Conv2D)   (None, 8, 8, 32)     36864       conv5_block27_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block27_concat (Concatena (None, 8, 8, 1504)   0           conv5_block26_concat[0][0]
#                                                                  conv5_block27_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block28_0_bn (BatchNormal (None, 8, 8, 1504)   6016        conv5_block27_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block28_0_relu (Activatio (None, 8, 8, 1504)   0           conv5_block28_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_conv (Conv2D)   (None, 8, 8, 128)    192512      conv5_block28_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_bn (BatchNormal (None, 8, 8, 128)    512         conv5_block28_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_relu (Activatio (None, 8, 8, 128)    0           conv5_block28_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block28_2_conv (Conv2D)   (None, 8, 8, 32)     36864       conv5_block28_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block28_concat (Concatena (None, 8, 8, 1536)   0           conv5_block27_concat[0][0]
#                                                                  conv5_block28_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block29_0_bn (BatchNormal (None, 8, 8, 1536)   6144        conv5_block28_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block29_0_relu (Activatio (None, 8, 8, 1536)   0           conv5_block29_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_conv (Conv2D)   (None, 8, 8, 128)    196608      conv5_block29_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_bn (BatchNormal (None, 8, 8, 128)    512         conv5_block29_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_relu (Activatio (None, 8, 8, 128)    0           conv5_block29_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block29_2_conv (Conv2D)   (None, 8, 8, 32)     36864       conv5_block29_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block29_concat (Concatena (None, 8, 8, 1568)   0           conv5_block28_concat[0][0]
#                                                                  conv5_block29_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block30_0_bn (BatchNormal (None, 8, 8, 1568)   6272        conv5_block29_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block30_0_relu (Activatio (None, 8, 8, 1568)   0           conv5_block30_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_conv (Conv2D)   (None, 8, 8, 128)    200704      conv5_block30_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_bn (BatchNormal (None, 8, 8, 128)    512         conv5_block30_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_relu (Activatio (None, 8, 8, 128)    0           conv5_block30_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block30_2_conv (Conv2D)   (None, 8, 8, 32)     36864       conv5_block30_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block30_concat (Concatena (None, 8, 8, 1600)   0           conv5_block29_concat[0][0]
#                                                                  conv5_block30_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_bn (BatchNormal (None, 8, 8, 1600)   6400        conv5_block30_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_relu (Activatio (None, 8, 8, 1600)   0           conv5_block31_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_conv (Conv2D)   (None, 8, 8, 128)    204800      conv5_block31_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_bn (BatchNormal (None, 8, 8, 128)    512         conv5_block31_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_relu (Activatio (None, 8, 8, 128)    0           conv5_block31_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block31_2_conv (Conv2D)   (None, 8, 8, 32)     36864       conv5_block31_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block31_concat (Concatena (None, 8, 8, 1632)   0           conv5_block30_concat[0][0]
#                                                                  conv5_block31_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_bn (BatchNormal (None, 8, 8, 1632)   6528        conv5_block31_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_relu (Activatio (None, 8, 8, 1632)   0           conv5_block32_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_conv (Conv2D)   (None, 8, 8, 128)    208896      conv5_block32_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_bn (BatchNormal (None, 8, 8, 128)    512         conv5_block32_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_relu (Activatio (None, 8, 8, 128)    0           conv5_block32_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block32_2_conv (Conv2D)   (None, 8, 8, 32)     36864       conv5_block32_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block32_concat (Concatena (None, 8, 8, 1664)   0           conv5_block31_concat[0][0]
#                                                                  conv5_block32_2_conv[0][0]
# __________________________________________________________________________________________________
# bn (BatchNormalization)         (None, 8, 8, 1664)   6656        conv5_block32_concat[0][0]
# __________________________________________________________________________________________________
# relu (Activation)               (None, 8, 8, 1664)   0           bn[0][0]
# ==================================================================================================
# Total params: 12,642,880
# Trainable params: 0
# Non-trainable params: 12,642,880
# __________________________________________________________________________________________________

# %%
# Using features from convolutional network for RF
feature_extractor=dense_model.predict(x_train)

features = feature_extractor.reshape(feature_extractor.shape[0], -1)

# %%
 #This is our X input to RF
X_for_RF = features

# %%
#RANDOM FOREST

from sklearn.ensemble import RandomForestClassifier
RF_model = RandomForestClassifier(n_estimators = 50, random_state = 42)

# %%
# Train the model on training data
RF_model.fit(X_for_RF, y_train)
# Out:
# RandomForestClassifier(n_estimators=50, random_state=42)

# %%
#Send test data through same feature extractor process
X_test_feature = dense_model.predict(x_test)
X_test_features = X_test_feature.reshape(X_test_feature.shape[0], -1)

# %%
#Now predict using the trained RF model. 
prediction_RF = RF_model.predict(X_test_features)
#Inverse le transform to get original label back. 
prediction_RF = le.inverse_transform(prediction_RF)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report,cohen_kappa_score

cm = confusion_matrix(test_labels, prediction_RF)
print(cm)
acc = accuracy_score(test_labels, prediction_RF)*100
print("Accuracy =",acc)
kappa = cohen_kappa_score(test_labels,prediction_RF)
print("kappa score = ",kappa)
print(classification_report(test_labels,prediction_RF))
sns.heatmap(cm, annot=True)
# Out:
# [[181  20]
#  [ 58 198]]
# Accuracy = 82.93216630196937
# kappa score =  0.6605207519856764
#               precision    recall  f1-score   support
#
#     fracture       0.76      0.90      0.82       201
# non-fracture       0.91      0.77      0.84       256
#
#     accuracy                           0.83       457
#    macro avg       0.83      0.84      0.83       457
# weighted avg       0.84      0.83      0.83       457
# <AxesSubplot:>
